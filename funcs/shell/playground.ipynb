# %%
import re
import csv

# Sample log data
log_data = """shell
Non-commercial dataset directory yahya/cmi_bids_NC already exists.
Processing participants.tsv in yahya/cmi_bids_R1...
Found non-commercial subjects in yahya/cmi_bids_R1.
Moving sub-NDARAA075AMK from yahya/cmi_bids_R1/sub-NDARAA075AMK to yahya/cmi_bids_NC/sub-NDARAA075AMK.
Moving sub-NDARAA112DMH from yahya/cmi_bids_R1/sub-NDARAA112DMH to yahya/cmi_bids_NC/sub-NDARAA112DMH.
Moving sub-NDARAA117NEJ from yahya/cmi_bids_R1/sub-NDARAA117NEJ to yahya/cmi_bids_NC/sub-NDARAA117NEJ.
Moving sub-NDARAD481FXF from yahya/cmi_bids_R1/sub-NDARAD481FXF to yahya/cmi_bids_NC/sub-NDARAD481FXF.
Moving sub-NDARAE012DGA from yahya/cmi_bids_R1/sub-NDARAE012DGA to yahya/cmi_bids_NC/sub-NDARAE012DGA.
Moving sub-NDARAE199TDD from yahya/cmi_bids_R1/sub-NDARAE199TDD to yahya/cmi_bids_NC/sub-NDARAE199TDD.
Moving sub-NDARAJ366ZFA from yahya/cmi_bids_R1/sub-NDARAJ366ZFA to yahya/cmi_bids_NC/sub-NDARAJ366ZFA.
Moving sub-NDARAJ807UYR from yahya/cmi_bids_R1/sub-NDARAJ807UYR to yahya/cmi_bids_NC/sub-NDARAJ807UYR.
Moving sub-NDARAK653RYE from yahya/cmi_bids_R1/sub-NDARAK653RYE to yahya/cmi_bids_NC/sub-NDARAK653RYE.
Moving sub-NDARAM048AFP from yahya/cmi_bids_R1/sub-NDARAM048AFP to yahya/cmi_bids_NC/sub-NDARAM048AFP.
Moving sub-NDARAM277WZT from yahya/cmi_bids_R1/sub-NDARAM277WZT to yahya/cmi_bids_NC/sub-NDARAM277WZT.
Moving sub-NDARAN461TGQ from yahya/cmi_bids_R1/sub-NDARAN461TGQ to yahya/cmi_bids_NC/sub-NDARAN461TGQ.
Moving sub-NDARAT100AEQ from yahya/cmi_bids_R1/sub-NDARAT100AEQ to yahya/cmi_bids_NC/sub-NDARAT100AEQ.
Moving sub-NDARAT299YRR from yahya/cmi_bids_R1/sub-NDARAT299YRR to yahya/cmi_bids_NC/sub-NDARAT299YRR.
Moving sub-NDARAU447JZH from yahya/cmi_bids_R1/sub-NDARAU447JZH to yahya/cmi_bids_NC/sub-NDARAU447JZH.
Moving sub-NDARAV534CJH from yahya/cmi_bids_R1/sub-NDARAV534CJH to yahya/cmi_bids_NC/sub-NDARAV534CJH.
Moving sub-NDARAV747WVL from yahya/cmi_bids_R1/sub-NDARAV747WVL to yahya/cmi_bids_NC/sub-NDARAV747WVL.
Moving sub-NDARAV894XWD from yahya/cmi_bids_R1/sub-NDARAV894XWD to yahya/cmi_bids_NC/sub-NDARAV894XWD.
Moving sub-NDARAY238DFL from yahya/cmi_bids_R1/sub-NDARAY238DFL to yahya/cmi_bids_NC/sub-NDARAY238DFL.
Moving sub-NDARAY734WB0 from yahya/cmi_bids_R1/sub-NDARAY734WB0 to yahya/cmi_bids_NC/sub-NDARAY734WB0.
Moving sub-NDARBA507GCT from yahya/cmi_bids_R1/sub-NDARBA507GCT to yahya/cmi_bids_NC/sub-NDARBA507GCT.
Moving sub-NDARBA521RA8 from yahya/cmi_bids_R1/sub-NDARBA521RA8 to yahya/cmi_bids_NC/sub-NDARBA521RA8.
Moving sub-NDARBB854DRN from yahya/cmi_bids_R1/sub-NDARBB854DRN to yahya/cmi_bids_NC/sub-NDARBB854DRN.
Moving sub-NDARBC580HR5 from yahya/cmi_bids_R1/sub-NDARBC580HR5 to yahya/cmi_bids_NC/sub-NDARBC580HR5.
Moving sub-NDARBD566RRW from yahya/cmi_bids_R1/sub-NDARBD566RRW to yahya/cmi_bids_NC/sub-NDARBD566RRW.
Moving sub-NDARBF805EHN from yahya/cmi_bids_R1/sub-NDARBF805EHN to yahya/cmi_bids_NC/sub-NDARBF805EHN.
Moving sub-NDARBK669XJQ from yahya/cmi_bids_R1/sub-NDARBK669XJQ to yahya/cmi_bids_NC/sub-NDARBK669XJQ.
Moving sub-NDARBL117AUV from yahya/cmi_bids_R1/sub-NDARBL117AUV to yahya/cmi_bids_NC/sub-NDARBL117AUV.
Moving sub-NDARBM213BEA from yahya/cmi_bids_R1/sub-NDARBM213BEA to yahya/cmi_bids_NC/sub-NDARBM213BEA.
Moving sub-NDARBN100LCD from yahya/cmi_bids_R1/sub-NDARBN100LCD to yahya/cmi_bids_NC/sub-NDARBN100LCD.
Moving sub-NDARBP894XHG from yahya/cmi_bids_R1/sub-NDARBP894XHG to yahya/cmi_bids_NC/sub-NDARBP894XHG.
Moving sub-NDARBT747UHM from yahya/cmi_bids_R1/sub-NDARBT747UHM to yahya/cmi_bids_NC/sub-NDARBT747UHM.
Moving sub-NDARBU112XZE from yahya/cmi_bids_R1/sub-NDARBU112XZE to yahya/cmi_bids_NC/sub-NDARBU112XZE.
Moving sub-NDARBV364MBC from yahya/cmi_bids_R1/sub-NDARBV364MBC to yahya/cmi_bids_NC/sub-NDARBV364MBC.
Moving sub-NDARBY518PRN from yahya/cmi_bids_R1/sub-NDARBY518PRN to yahya/cmi_bids_NC/sub-NDARBY518PRN.
Moving sub-NDARCA186WGH from yahya/cmi_bids_R1/sub-NDARCA186WGH to yahya/cmi_bids_NC/sub-NDARCA186WGH.
Moving sub-NDARCA789EE0 from yahya/cmi_bids_R1/sub-NDARCA789EE0 to yahya/cmi_bids_NC/sub-NDARCA789EE0.
Moving sub-NDARCB370UK4 from yahya/cmi_bids_R1/sub-NDARCB370UK4 to yahya/cmi_bids_NC/sub-NDARCB370UK4.
Moving sub-NDARCD401HGZ from yahya/cmi_bids_R1/sub-NDARCD401HGZ to yahya/cmi_bids_NC/sub-NDARCD401HGZ.
Moving sub-NDARCE353XKH from yahya/cmi_bids_R1/sub-NDARCE353XKH to yahya/cmi_bids_NC/sub-NDARCE353XKH.
Moving sub-NDARCE368YHM from yahya/cmi_bids_R1/sub-NDARCE368YHM to yahya/cmi_bids_NC/sub-NDARCE368YHM.
Moving sub-NDARCF247TDJ from yahya/cmi_bids_R1/sub-NDARCF247TDJ to yahya/cmi_bids_NC/sub-NDARCF247TDJ.
Moving sub-NDARCG984YXZ from yahya/cmi_bids_R1/sub-NDARCG984YXZ to yahya/cmi_bids_NC/sub-NDARCG984YXZ.
Moving sub-NDARCH755XDL from yahya/cmi_bids_R1/sub-NDARCH755XDL to yahya/cmi_bids_NC/sub-NDARCH755XDL.
Moving sub-NDARCJ363KLE from yahya/cmi_bids_R1/sub-NDARCJ363KLE to yahya/cmi_bids_NC/sub-NDARCJ363KLE.
Moving sub-NDARCL080RHP from yahya/cmi_bids_R1/sub-NDARCL080RHP to yahya/cmi_bids_NC/sub-NDARCL080RHP.
Moving sub-NDARCP360AFD from yahya/cmi_bids_R1/sub-NDARCP360AFD to yahya/cmi_bids_NC/sub-NDARCP360AFD.
Moving sub-NDARCT472UJ7 from yahya/cmi_bids_R1/sub-NDARCT472UJ7 to yahya/cmi_bids_NC/sub-NDARCT472UJ7.
Moving sub-NDARCT933HF2 from yahya/cmi_bids_R1/sub-NDARCT933HF2 to yahya/cmi_bids_NC/sub-NDARCT933HF2.
Moving sub-NDARCU034JPB from yahya/cmi_bids_R1/sub-NDARCU034JPB to yahya/cmi_bids_NC/sub-NDARCU034JPB.
Moving sub-NDARCU417HRA from yahya/cmi_bids_R1/sub-NDARCU417HRA to yahya/cmi_bids_NC/sub-NDARCU417HRA.
Moving sub-NDARCW419GBD from yahya/cmi_bids_R1/sub-NDARCW419GBD to yahya/cmi_bids_NC/sub-NDARCW419GBD.
Moving sub-NDARCW963FP9 from yahya/cmi_bids_R1/sub-NDARCW963FP9 to yahya/cmi_bids_NC/sub-NDARCW963FP9.
Moving sub-NDARCX221CWA from yahya/cmi_bids_R1/sub-NDARCX221CWA to yahya/cmi_bids_NC/sub-NDARCX221CWA.
Moving sub-NDARCX580WB7 from yahya/cmi_bids_R1/sub-NDARCX580WB7 to yahya/cmi_bids_NC/sub-NDARCX580WB7.
Moving sub-NDARDB146NWY from yahya/cmi_bids_R1/sub-NDARDB146NWY to yahya/cmi_bids_NC/sub-NDARDB146NWY.
Moving sub-NDARDB804YHE from yahya/cmi_bids_R1/sub-NDARDB804YHE to yahya/cmi_bids_NC/sub-NDARDB804YHE.
Moving sub-NDARDH328DR9 from yahya/cmi_bids_R1/sub-NDARDH328DR9 to yahya/cmi_bids_NC/sub-NDARDH328DR9.
Moving sub-NDARDJ585AVY from yahya/cmi_bids_R1/sub-NDARDJ585AVY to yahya/cmi_bids_NC/sub-NDARDJ585AVY.
Moving sub-NDARDJ825GBP from yahya/cmi_bids_R1/sub-NDARDJ825GBP to yahya/cmi_bids_NC/sub-NDARDJ825GBP.
Moving sub-NDARDL862DP6 from yahya/cmi_bids_R1/sub-NDARDL862DP6 to yahya/cmi_bids_NC/sub-NDARDL862DP6.
Moving sub-NDARDM425CG2 from yahya/cmi_bids_R1/sub-NDARDM425CG2 to yahya/cmi_bids_NC/sub-NDARDM425CG2.
Moving sub-NDARDN702GXX from yahya/cmi_bids_R1/sub-NDARDN702GXX to yahya/cmi_bids_NC/sub-NDARDN702GXX.
Moving sub-NDARDV310UEG from yahya/cmi_bids_R1/sub-NDARDV310UEG to yahya/cmi_bids_NC/sub-NDARDV310UEG.
Moving sub-NDARDX469TC1 from yahya/cmi_bids_R1/sub-NDARDX469TC1 to yahya/cmi_bids_NC/sub-NDARDX469TC1.
Moving sub-NDARDX770PJK from yahya/cmi_bids_R1/sub-NDARDX770PJK to yahya/cmi_bids_NC/sub-NDARDX770PJK.
Moving sub-NDARDZ946KVL from yahya/cmi_bids_R1/sub-NDARDZ946KVL to yahya/cmi_bids_NC/sub-NDARDZ946KVL.
Moving sub-NDAREB290UCN from yahya/cmi_bids_R1/sub-NDAREB290UCN to yahya/cmi_bids_NC/sub-NDAREB290UCN.
Moving sub-NDAREC182WW2 from yahya/cmi_bids_R1/sub-NDAREC182WW2 to yahya/cmi_bids_NC/sub-NDAREC182WW2.
Moving sub-NDARED047DTH from yahya/cmi_bids_R1/sub-NDARED047DTH to yahya/cmi_bids_NC/sub-NDARED047DTH.
Moving sub-NDAREE196FEG from yahya/cmi_bids_R1/sub-NDAREE196FEG to yahya/cmi_bids_NC/sub-NDAREE196FEG.
Moving sub-NDAREF057VX5 from yahya/cmi_bids_R1/sub-NDAREF057VX5 to yahya/cmi_bids_NC/sub-NDAREF057VX5.
Moving sub-NDAREH876HG2 from yahya/cmi_bids_R1/sub-NDAREH876HG2 to yahya/cmi_bids_NC/sub-NDAREH876HG2.
Moving sub-NDAREH905REB from yahya/cmi_bids_R1/sub-NDAREH905REB to yahya/cmi_bids_NC/sub-NDAREH905REB.
Moving sub-NDAREK375DKR from yahya/cmi_bids_R1/sub-NDAREK375DKR to yahya/cmi_bids_NC/sub-NDAREK375DKR.
Moving sub-NDAREK544ENR from yahya/cmi_bids_R1/sub-NDAREK544ENR to yahya/cmi_bids_NC/sub-NDAREK544ENR.
Moving sub-NDAREK918EC2 from yahya/cmi_bids_R1/sub-NDAREK918EC2 to yahya/cmi_bids_NC/sub-NDAREK918EC2.
Moving sub-NDAREK947FYP from yahya/cmi_bids_R1/sub-NDAREK947FYP to yahya/cmi_bids_NC/sub-NDAREK947FYP.
Moving sub-NDAREL622FA6 from yahya/cmi_bids_R1/sub-NDAREL622FA6 to yahya/cmi_bids_NC/sub-NDAREL622FA6.
Moving sub-NDAREM018TJQ from yahya/cmi_bids_R1/sub-NDAREM018TJQ to yahya/cmi_bids_NC/sub-NDAREM018TJQ.
Moving sub-NDAREM141CKP from yahya/cmi_bids_R1/sub-NDAREM141CKP to yahya/cmi_bids_NC/sub-NDAREM141CKP.
Moving sub-NDARER840MKU from yahya/cmi_bids_R1/sub-NDARER840MKU to yahya/cmi_bids_NC/sub-NDARER840MKU.
Moving sub-NDARET653TAM from yahya/cmi_bids_R1/sub-NDARET653TAM to yahya/cmi_bids_NC/sub-NDARET653TAM.
Moving sub-NDARET893AK8 from yahya/cmi_bids_R1/sub-NDARET893AK8 to yahya/cmi_bids_NC/sub-NDARET893AK8.
Moving sub-NDARET949LMU from yahya/cmi_bids_R1/sub-NDARET949LMU to yahya/cmi_bids_NC/sub-NDARET949LMU.
Moving sub-NDAREU551GPC from yahya/cmi_bids_R1/sub-NDAREU551GPC to yahya/cmi_bids_NC/sub-NDAREU551GPC.
Moving sub-NDAREV970HAN from yahya/cmi_bids_R1/sub-NDAREV970HAN to yahya/cmi_bids_NC/sub-NDAREV970HAN.
Moving sub-NDAREW976FNL from yahya/cmi_bids_R1/sub-NDAREW976FNL to yahya/cmi_bids_NC/sub-NDAREW976FNL.
Moving sub-NDAREX091KUR from yahya/cmi_bids_R1/sub-NDAREX091KUR to yahya/cmi_bids_NC/sub-NDAREX091KUR.
Moving sub-NDAREY741MG9 from yahya/cmi_bids_R1/sub-NDAREY741MG9 to yahya/cmi_bids_NC/sub-NDAREY741MG9.
Moving sub-NDAREZ098ZPE from yahya/cmi_bids_R1/sub-NDAREZ098ZPE to yahya/cmi_bids_NC/sub-NDAREZ098ZPE.
Moving sub-NDARFA860RPD from yahya/cmi_bids_R1/sub-NDARFA860RPD to yahya/cmi_bids_NC/sub-NDARFA860RPD.
Moving sub-NDARFB575BAT from yahya/cmi_bids_R1/sub-NDARFB575BAT to yahya/cmi_bids_NC/sub-NDARFB575BAT.
Moving sub-NDARFE163HVN from yahya/cmi_bids_R1/sub-NDARFE163HVN to yahya/cmi_bids_NC/sub-NDARFE163HVN.
Moving sub-NDARFG114VB1 from yahya/cmi_bids_R1/sub-NDARFG114VB1 to yahya/cmi_bids_NC/sub-NDARFG114VB1.
Moving sub-NDARFH674DWX from yahya/cmi_bids_R1/sub-NDARFH674DWX to yahya/cmi_bids_NC/sub-NDARFH674DWX.
Moving sub-NDARFJ100BDZ from yahya/cmi_bids_R1/sub-NDARFJ100BDZ to yahya/cmi_bids_NC/sub-NDARFJ100BDZ.
Moving sub-NDARFJ302HVD from yahya/cmi_bids_R1/sub-NDARFJ302HVD to yahya/cmi_bids_NC/sub-NDARFJ302HVD.
Moving sub-NDARFL411AT1 from yahya/cmi_bids_R1/sub-NDARFL411AT1 to yahya/cmi_bids_NC/sub-NDARFL411AT1.
Moving sub-NDARFM080VAF from yahya/cmi_bids_R1/sub-NDARFM080VAF to yahya/cmi_bids_NC/sub-NDARFM080VAF.
Moving sub-NDARFN452VPC from yahya/cmi_bids_R1/sub-NDARFN452VPC to yahya/cmi_bids_NC/sub-NDARFN452VPC.
Moving sub-NDARFT834NT1 from yahya/cmi_bids_R1/sub-NDARFT834NT1 to yahya/cmi_bids_NC/sub-NDARFT834NT1.
Moving sub-NDARFW292PBD from yahya/cmi_bids_R1/sub-NDARFW292PBD to yahya/cmi_bids_NC/sub-NDARFW292PBD.
Moving sub-NDARFW444PN1 from yahya/cmi_bids_R1/sub-NDARFW444PN1 to yahya/cmi_bids_NC/sub-NDARFW444PN1.
Moving sub-NDARFX721WR8 from yahya/cmi_bids_R1/sub-NDARFX721WR8 to yahya/cmi_bids_NC/sub-NDARFX721WR8.
Moving sub-NDARFY075REK from yahya/cmi_bids_R1/sub-NDARFY075REK to yahya/cmi_bids_NC/sub-NDARFY075REK.
Moving sub-NDARFY612EMR from yahya/cmi_bids_R1/sub-NDARFY612EMR to yahya/cmi_bids_NC/sub-NDARFY612EMR.
Moving sub-NDARFZ296UNG from yahya/cmi_bids_R1/sub-NDARFZ296UNG to yahya/cmi_bids_NC/sub-NDARFZ296UNG.
Moving sub-NDARGC521HNP from yahya/cmi_bids_R1/sub-NDARGC521HNP to yahya/cmi_bids_NC/sub-NDARGC521HNP.
Moving sub-NDARGE366WNC from yahya/cmi_bids_R1/sub-NDARGE366WNC to yahya/cmi_bids_NC/sub-NDARGE366WNC.
Moving sub-NDARGE536BGD from yahya/cmi_bids_R1/sub-NDARGE536BGD to yahya/cmi_bids_NC/sub-NDARGE536BGD.
Moving sub-NDARGH407KVG from yahya/cmi_bids_R1/sub-NDARGH407KVG to yahya/cmi_bids_NC/sub-NDARGH407KVG.
Moving sub-NDARGH492CF1 from yahya/cmi_bids_R1/sub-NDARGH492CF1 to yahya/cmi_bids_NC/sub-NDARGH492CF1.
Moving sub-NDARGJ761GA8 from yahya/cmi_bids_R1/sub-NDARGJ761GA8 to yahya/cmi_bids_NC/sub-NDARGJ761GA8.
Moving sub-NDARGL107GFK from yahya/cmi_bids_R1/sub-NDARGL107GFK to yahya/cmi_bids_NC/sub-NDARGL107GFK.
Moving sub-NDARGL834CMQ from yahya/cmi_bids_R1/sub-NDARGL834CMQ to yahya/cmi_bids_NC/sub-NDARGL834CMQ.
Moving sub-NDARGL963HU4 from yahya/cmi_bids_R1/sub-NDARGL963HU4 to yahya/cmi_bids_NC/sub-NDARGL963HU4.
Moving sub-NDARGM498YFL from yahya/cmi_bids_R1/sub-NDARGM498YFL to yahya/cmi_bids_NC/sub-NDARGM498YFL.
Moving sub-NDARGM540EV8 from yahya/cmi_bids_R1/sub-NDARGM540EV8 to yahya/cmi_bids_NC/sub-NDARGM540EV8.
Moving sub-NDARGN148MK2 from yahya/cmi_bids_R1/sub-NDARGN148MK2 to yahya/cmi_bids_NC/sub-NDARGN148MK2.
Moving sub-NDARGR661YZG from yahya/cmi_bids_R1/sub-NDARGR661YZG to yahya/cmi_bids_NC/sub-NDARGR661YZG.
Moving sub-NDARGR875AXY from yahya/cmi_bids_R1/sub-NDARGR875AXY to yahya/cmi_bids_NC/sub-NDARGR875AXY.
Moving sub-NDARGT022BEW from yahya/cmi_bids_R1/sub-NDARGT022BEW to yahya/cmi_bids_NC/sub-NDARGT022BEW.
Moving sub-NDARGT267UZR from yahya/cmi_bids_R1/sub-NDARGT267UZR to yahya/cmi_bids_NC/sub-NDARGT267UZR.
Moving sub-NDARGU100JH4 from yahya/cmi_bids_R1/sub-NDARGU100JH4 to yahya/cmi_bids_NC/sub-NDARGU100JH4.
Moving sub-NDARGU485JJA from yahya/cmi_bids_R1/sub-NDARGU485JJA to yahya/cmi_bids_NC/sub-NDARGU485JJA.
Moving sub-NDARGU667MCK from yahya/cmi_bids_R1/sub-NDARGU667MCK to yahya/cmi_bids_NC/sub-NDARGU667MCK.
Moving sub-NDARGV956EGX from yahya/cmi_bids_R1/sub-NDARGV956EGX to yahya/cmi_bids_NC/sub-NDARGV956EGX.
Moving sub-NDARGW362UJZ from yahya/cmi_bids_R1/sub-NDARGW362UJZ to yahya/cmi_bids_NC/sub-NDARGW362UJZ.
Moving sub-NDARGY054ENV from yahya/cmi_bids_R1/sub-NDARGY054ENV to yahya/cmi_bids_NC/sub-NDARGY054ENV.
Moving sub-NDARGY148EVU from yahya/cmi_bids_R1/sub-NDARGY148EVU to yahya/cmi_bids_NC/sub-NDARGY148EVU.
Moving sub-NDARHB000YF8 from yahya/cmi_bids_R1/sub-NDARHB000YF8 to yahya/cmi_bids_NC/sub-NDARHB000YF8.
Moving sub-NDARHB772TE5 from yahya/cmi_bids_R1/sub-NDARHB772TE5 to yahya/cmi_bids_NC/sub-NDARHB772TE5.
Moving sub-NDARHB781DD8 from yahya/cmi_bids_R1/sub-NDARHB781DD8 to yahya/cmi_bids_NC/sub-NDARHB781DD8.
Moving sub-NDARHB993EV0 from yahya/cmi_bids_R1/sub-NDARHB993EV0 to yahya/cmi_bids_NC/sub-NDARHB993EV0.
Moving sub-NDARHC287ZF4 from yahya/cmi_bids_R1/sub-NDARHC287ZF4 to yahya/cmi_bids_NC/sub-NDARHC287ZF4.
Moving sub-NDARHC737MHK from yahya/cmi_bids_R1/sub-NDARHC737MHK to yahya/cmi_bids_NC/sub-NDARHC737MHK.
Moving sub-NDARHD059PEQ from yahya/cmi_bids_R1/sub-NDARHD059PEQ to yahya/cmi_bids_NC/sub-NDARHD059PEQ.
Moving sub-NDARHE236YLB from yahya/cmi_bids_R1/sub-NDARHE236YLB to yahya/cmi_bids_NC/sub-NDARHE236YLB.
Moving sub-NDARHF269ATU from yahya/cmi_bids_R1/sub-NDARHF269ATU to yahya/cmi_bids_NC/sub-NDARHF269ATU.
Moving sub-NDARHF904CWB from yahya/cmi_bids_R1/sub-NDARHF904CWB to yahya/cmi_bids_NC/sub-NDARHF904CWB.
Moving sub-NDARHJ126UW2 from yahya/cmi_bids_R1/sub-NDARHJ126UW2 to yahya/cmi_bids_NC/sub-NDARHJ126UW2.
Moving sub-NDARHJ523XGB from yahya/cmi_bids_R1/sub-NDARHJ523XGB to yahya/cmi_bids_NC/sub-NDARHJ523XGB.
Moving sub-NDARHK598YJC from yahya/cmi_bids_R1/sub-NDARHK598YJC to yahya/cmi_bids_NC/sub-NDARHK598YJC.
Moving sub-NDARHL238VL2 from yahya/cmi_bids_R1/sub-NDARHL238VL2 to yahya/cmi_bids_NC/sub-NDARHL238VL2.
Moving sub-NDARHM273AXL from yahya/cmi_bids_R1/sub-NDARHM273AXL to yahya/cmi_bids_NC/sub-NDARHM273AXL.
Moving sub-NDARHN131ZP6 from yahya/cmi_bids_R1/sub-NDARHN131ZP6 to yahya/cmi_bids_NC/sub-NDARHN131ZP6.
Moving sub-NDARHP176DPE from yahya/cmi_bids_R1/sub-NDARHP176DPE to yahya/cmi_bids_NC/sub-NDARHP176DPE.
Moving sub-NDARHP558MGA from yahya/cmi_bids_R1/sub-NDARHP558MGA to yahya/cmi_bids_NC/sub-NDARHP558MGA.
Moving sub-NDARHR944BBY from yahya/cmi_bids_R1/sub-NDARHR944BBY to yahya/cmi_bids_NC/sub-NDARHR944BBY.
Moving sub-NDARHT218GFA from yahya/cmi_bids_R1/sub-NDARHT218GFA to yahya/cmi_bids_NC/sub-NDARHT218GFA.
Moving sub-NDARHU391FD7 from yahya/cmi_bids_R1/sub-NDARHU391FD7 to yahya/cmi_bids_NC/sub-NDARHU391FD7.
Moving sub-NDARHV527DNK from yahya/cmi_bids_R1/sub-NDARHV527DNK to yahya/cmi_bids_NC/sub-NDARHV527DNK.
Moving sub-NDARHW650FXU from yahya/cmi_bids_R1/sub-NDARHW650FXU to yahya/cmi_bids_NC/sub-NDARHW650FXU.
Moving sub-NDARHW718DTW from yahya/cmi_bids_R1/sub-NDARHW718DTW to yahya/cmi_bids_NC/sub-NDARHW718DTW.
Moving sub-NDARHX739YBW from yahya/cmi_bids_R1/sub-NDARHX739YBW to yahya/cmi_bids_NC/sub-NDARHX739YBW.
Moving sub-NDARHX877BLQ from yahya/cmi_bids_R1/sub-NDARHX877BLQ to yahya/cmi_bids_NC/sub-NDARHX877BLQ.
Moving sub-NDARHZ439EBY from yahya/cmi_bids_R1/sub-NDARHZ439EBY to yahya/cmi_bids_NC/sub-NDARHZ439EBY.
Moving sub-NDARJD282HJ4 from yahya/cmi_bids_R1/sub-NDARJD282HJ4 to yahya/cmi_bids_NC/sub-NDARJD282HJ4.
Moving sub-NDARJE086YU0 from yahya/cmi_bids_R1/sub-NDARJE086YU0 to yahya/cmi_bids_NC/sub-NDARJE086YU0.
Moving sub-NDARJF045MHG from yahya/cmi_bids_R1/sub-NDARJF045MHG to yahya/cmi_bids_NC/sub-NDARJF045MHG.
Moving sub-NDARJH441HJD from yahya/cmi_bids_R1/sub-NDARJH441HJD to yahya/cmi_bids_NC/sub-NDARJH441HJD.
Moving sub-NDARJH925ZCD from yahya/cmi_bids_R1/sub-NDARJH925ZCD to yahya/cmi_bids_NC/sub-NDARJH925ZCD.
Moving sub-NDARJJ356DAL from yahya/cmi_bids_R1/sub-NDARJJ356DAL to yahya/cmi_bids_NC/sub-NDARJJ356DAL.
Moving sub-NDARJJ859RRW from yahya/cmi_bids_R1/sub-NDARJJ859RRW to yahya/cmi_bids_NC/sub-NDARJJ859RRW.
Moving sub-NDARJL058RDV from yahya/cmi_bids_R1/sub-NDARJL058RDV to yahya/cmi_bids_NC/sub-NDARJL058RDV.
Moving sub-NDARJM708VGE from yahya/cmi_bids_R1/sub-NDARJM708VGE to yahya/cmi_bids_NC/sub-NDARJM708VGE.
Moving sub-NDARJM759GYH from yahya/cmi_bids_R1/sub-NDARJM759GYH to yahya/cmi_bids_NC/sub-NDARJM759GYH.
Moving sub-NDARJP489HCE from yahya/cmi_bids_R1/sub-NDARJP489HCE to yahya/cmi_bids_NC/sub-NDARJP489HCE.
Moving sub-NDARJR525HTX from yahya/cmi_bids_R1/sub-NDARJR525HTX to yahya/cmi_bids_NC/sub-NDARJR525HTX.
Moving sub-NDARJR687LGX from yahya/cmi_bids_R1/sub-NDARJR687LGX to yahya/cmi_bids_NC/sub-NDARJR687LGX.
Moving sub-NDARJT523MV7 from yahya/cmi_bids_R1/sub-NDARJT523MV7 to yahya/cmi_bids_NC/sub-NDARJT523MV7.
Moving sub-NDARJT730WP0 from yahya/cmi_bids_R1/sub-NDARJT730WP0 to yahya/cmi_bids_NC/sub-NDARJT730WP0.
Moving sub-NDARJU766FBU from yahya/cmi_bids_R1/sub-NDARJU766FBU to yahya/cmi_bids_NC/sub-NDARJU766FBU.
Moving sub-NDARJW315BUA from yahya/cmi_bids_R1/sub-NDARJW315BUA to yahya/cmi_bids_NC/sub-NDARJW315BUA.
Moving sub-NDARJX421FWR from yahya/cmi_bids_R1/sub-NDARJX421FWR to yahya/cmi_bids_NC/sub-NDARJX421FWR.
Moving sub-NDARJZ549HU8 from yahya/cmi_bids_R1/sub-NDARJZ549HU8 to yahya/cmi_bids_NC/sub-NDARJZ549HU8.
Moving sub-NDARJZ715FE8 from yahya/cmi_bids_R1/sub-NDARJZ715FE8 to yahya/cmi_bids_NC/sub-NDARJZ715FE8.
Moving sub-NDARKA429EPF from yahya/cmi_bids_R1/sub-NDARKA429EPF to yahya/cmi_bids_NC/sub-NDARKA429EPF.
Moving sub-NDARKE331EHD from yahya/cmi_bids_R1/sub-NDARKE331EHD to yahya/cmi_bids_NC/sub-NDARKE331EHD.
Moving sub-NDARKG785VAJ from yahya/cmi_bids_R1/sub-NDARKG785VAJ to yahya/cmi_bids_NC/sub-NDARKG785VAJ.
Moving sub-NDARKG859AGN from yahya/cmi_bids_R1/sub-NDARKG859AGN to yahya/cmi_bids_NC/sub-NDARKG859AGN.
Moving sub-NDARKH421UB1 from yahya/cmi_bids_R1/sub-NDARKH421UB1 to yahya/cmi_bids_NC/sub-NDARKH421UB1.
Moving sub-NDARKL637YBF from yahya/cmi_bids_R1/sub-NDARKL637YBF to yahya/cmi_bids_NC/sub-NDARKL637YBF.
Moving sub-NDARKM497VKX from yahya/cmi_bids_R1/sub-NDARKM497VKX to yahya/cmi_bids_NC/sub-NDARKM497VKX.
Moving sub-NDARKM551DA4 from yahya/cmi_bids_R1/sub-NDARKM551DA4 to yahya/cmi_bids_NC/sub-NDARKM551DA4.
Moving sub-NDARKR010EN7 from yahya/cmi_bids_R1/sub-NDARKR010EN7 to yahya/cmi_bids_NC/sub-NDARKR010EN7.
Moving sub-NDARKR195PL9 from yahya/cmi_bids_R1/sub-NDARKR195PL9 to yahya/cmi_bids_NC/sub-NDARKR195PL9.
Moving sub-NDARKU043JMU from yahya/cmi_bids_R1/sub-NDARKU043JMU to yahya/cmi_bids_NC/sub-NDARKU043JMU.
Moving sub-NDARKW145LNX from yahya/cmi_bids_R1/sub-NDARKW145LNX to yahya/cmi_bids_NC/sub-NDARKW145LNX.
Moving sub-NDARKX346VTV from yahya/cmi_bids_R1/sub-NDARKX346VTV to yahya/cmi_bids_NC/sub-NDARKX346VTV.
Moving sub-NDARKX761BH9 from yahya/cmi_bids_R1/sub-NDARKX761BH9 to yahya/cmi_bids_NC/sub-NDARKX761BH9.
Moving sub-NDARLA395AG8 from yahya/cmi_bids_R1/sub-NDARLA395AG8 to yahya/cmi_bids_NC/sub-NDARLA395AG8.
Moving sub-NDARLA516PH1 from yahya/cmi_bids_R1/sub-NDARLA516PH1 to yahya/cmi_bids_NC/sub-NDARLA516PH1.
Moving sub-NDARLA623HN3 from yahya/cmi_bids_R1/sub-NDARLA623HN3 to yahya/cmi_bids_NC/sub-NDARLA623HN3.
Moving sub-NDARLB017MBJ from yahya/cmi_bids_R1/sub-NDARLB017MBJ to yahya/cmi_bids_NC/sub-NDARLB017MBJ.
Moving sub-NDARLB629BJ1 from yahya/cmi_bids_R1/sub-NDARLB629BJ1 to yahya/cmi_bids_NC/sub-NDARLB629BJ1.
Moving sub-NDARLC358CYJ from yahya/cmi_bids_R1/sub-NDARLC358CYJ to yahya/cmi_bids_NC/sub-NDARLC358CYJ.
Moving sub-NDARLC868GLL from yahya/cmi_bids_R1/sub-NDARLC868GLL to yahya/cmi_bids_NC/sub-NDARLC868GLL.
Moving sub-NDARLD990NH4 from yahya/cmi_bids_R1/sub-NDARLD990NH4 to yahya/cmi_bids_NC/sub-NDARLD990NH4.
Moving sub-NDARLE953JYU from yahya/cmi_bids_R1/sub-NDARLE953JYU to yahya/cmi_bids_NC/sub-NDARLE953JYU.
Moving sub-NDARLF283KJX from yahya/cmi_bids_R1/sub-NDARLF283KJX to yahya/cmi_bids_NC/sub-NDARLF283KJX.
Moving sub-NDARLF480DMW from yahya/cmi_bids_R1/sub-NDARLF480DMW to yahya/cmi_bids_NC/sub-NDARLF480DMW.
Moving sub-NDARLG027HUK from yahya/cmi_bids_R1/sub-NDARLG027HUK to yahya/cmi_bids_NC/sub-NDARLG027HUK.
Moving sub-NDARLG890JDU from yahya/cmi_bids_R1/sub-NDARLG890JDU to yahya/cmi_bids_NC/sub-NDARLG890JDU.
Moving sub-NDARLG942AZ1 from yahya/cmi_bids_R1/sub-NDARLG942AZ1 to yahya/cmi_bids_NC/sub-NDARLG942AZ1.
Moving sub-NDARLJ311YNA from yahya/cmi_bids_R1/sub-NDARLJ311YNA to yahya/cmi_bids_NC/sub-NDARLJ311YNA.
Moving sub-NDARLJ549WTT from yahya/cmi_bids_R1/sub-NDARLJ549WTT to yahya/cmi_bids_NC/sub-NDARLJ549WTT.
Moving sub-NDARLV086DEH from yahya/cmi_bids_R1/sub-NDARLV086DEH to yahya/cmi_bids_NC/sub-NDARLV086DEH.
Moving sub-NDARLW308UR0 from yahya/cmi_bids_R1/sub-NDARLW308UR0 to yahya/cmi_bids_NC/sub-NDARLW308UR0.
Moving sub-NDARLX816JUZ from yahya/cmi_bids_R1/sub-NDARLX816JUZ to yahya/cmi_bids_NC/sub-NDARLX816JUZ.
Moving sub-NDARLY067FD6 from yahya/cmi_bids_R1/sub-NDARLY067FD6 to yahya/cmi_bids_NC/sub-NDARLY067FD6.
Moving sub-NDARLZ104NDT from yahya/cmi_bids_R1/sub-NDARLZ104NDT to yahya/cmi_bids_NC/sub-NDARLZ104NDT.
Moving sub-NDARLZ228PCB from yahya/cmi_bids_R1/sub-NDARLZ228PCB to yahya/cmi_bids_NC/sub-NDARLZ228PCB.
Moving sub-NDARMC759CX3 from yahya/cmi_bids_R1/sub-NDARMC759CX3 to yahya/cmi_bids_NC/sub-NDARMC759CX3.
Moving sub-NDARME656MTN from yahya/cmi_bids_R1/sub-NDARME656MTN to yahya/cmi_bids_NC/sub-NDARME656MTN.
Moving sub-NDARME930DE7 from yahya/cmi_bids_R1/sub-NDARME930DE7 to yahya/cmi_bids_NC/sub-NDARME930DE7.
Moving sub-NDARMG278GYH from yahya/cmi_bids_R1/sub-NDARMG278GYH to yahya/cmi_bids_NC/sub-NDARMG278GYH.
Moving sub-NDARMH625WKL from yahya/cmi_bids_R1/sub-NDARMH625WKL to yahya/cmi_bids_NC/sub-NDARMH625WKL.
Moving sub-NDARMH677JDM from yahya/cmi_bids_R1/sub-NDARMH677JDM to yahya/cmi_bids_NC/sub-NDARMH677JDM.
Moving sub-NDARMH763YZD from yahya/cmi_bids_R1/sub-NDARMH763YZD to yahya/cmi_bids_NC/sub-NDARMH763YZD.
Moving sub-NDARMJ219AKU from yahya/cmi_bids_R1/sub-NDARMJ219AKU to yahya/cmi_bids_NC/sub-NDARMJ219AKU.
Moving sub-NDARML148UCE from yahya/cmi_bids_R1/sub-NDARML148UCE to yahya/cmi_bids_NC/sub-NDARML148UCE.
Moving sub-NDARML926NEG from yahya/cmi_bids_R1/sub-NDARML926NEG to yahya/cmi_bids_NC/sub-NDARML926NEG.
Moving sub-NDARMM782KJK from yahya/cmi_bids_R1/sub-NDARMM782KJK to yahya/cmi_bids_NC/sub-NDARMM782KJK.
Moving sub-NDARMM878ZR1 from yahya/cmi_bids_R1/sub-NDARMM878ZR1 to yahya/cmi_bids_NC/sub-NDARMM878ZR1.
Moving sub-NDARMM905VYR from yahya/cmi_bids_R1/sub-NDARMM905VYR to yahya/cmi_bids_NC/sub-NDARMM905VYR.
Moving sub-NDARMM990URX from yahya/cmi_bids_R1/sub-NDARMM990URX to yahya/cmi_bids_NC/sub-NDARMM990URX.
Moving sub-NDARMR242UKQ from yahya/cmi_bids_R1/sub-NDARMR242UKQ to yahya/cmi_bids_NC/sub-NDARMR242UKQ.
Moving sub-NDARMR277TT7 from yahya/cmi_bids_R1/sub-NDARMR277TT7 to yahya/cmi_bids_NC/sub-NDARMR277TT7.
Moving sub-NDARMT271DT6 from yahya/cmi_bids_R1/sub-NDARMT271DT6 to yahya/cmi_bids_NC/sub-NDARMT271DT6.
Moving sub-NDARMT898BME from yahya/cmi_bids_R1/sub-NDARMT898BME to yahya/cmi_bids_NC/sub-NDARMT898BME.
Moving sub-NDARMU269TFY from yahya/cmi_bids_R1/sub-NDARMU269TFY to yahya/cmi_bids_NC/sub-NDARMU269TFY.
Moving sub-NDARMV247HRA from yahya/cmi_bids_R1/sub-NDARMV247HRA to yahya/cmi_bids_NC/sub-NDARMV247HRA.
Moving sub-NDARMV410ZFY from yahya/cmi_bids_R1/sub-NDARMV410ZFY to yahya/cmi_bids_NC/sub-NDARMV410ZFY.
Moving sub-NDARMW178UDD from yahya/cmi_bids_R1/sub-NDARMW178UDD to yahya/cmi_bids_NC/sub-NDARMW178UDD.
Moving sub-NDARMW252AJW from yahya/cmi_bids_R1/sub-NDARMW252AJW to yahya/cmi_bids_NC/sub-NDARMW252AJW.
Moving sub-NDARMY301WFK from yahya/cmi_bids_R1/sub-NDARMY301WFK to yahya/cmi_bids_NC/sub-NDARMY301WFK.
Moving sub-NDARMY533CYM from yahya/cmi_bids_R1/sub-NDARMY533CYM to yahya/cmi_bids_NC/sub-NDARMY533CYM.
Moving sub-NDARMY967HNA from yahya/cmi_bids_R1/sub-NDARMY967HNA to yahya/cmi_bids_NC/sub-NDARMY967HNA.
Moving sub-NDARMZ908DUR from yahya/cmi_bids_R1/sub-NDARMZ908DUR to yahya/cmi_bids_NC/sub-NDARMZ908DUR.
Moving sub-NDARNB824ARJ from yahya/cmi_bids_R1/sub-NDARNB824ARJ to yahya/cmi_bids_NC/sub-NDARNB824ARJ.
Moving sub-NDARNE767VAJ from yahya/cmi_bids_R1/sub-NDARNE767VAJ to yahya/cmi_bids_NC/sub-NDARNE767VAJ.
Moving sub-NDARNF384JN0 from yahya/cmi_bids_R1/sub-NDARNF384JN0 to yahya/cmi_bids_NC/sub-NDARNF384JN0.
Moving sub-NDARNF766VW2 from yahya/cmi_bids_R1/sub-NDARNF766VW2 to yahya/cmi_bids_NC/sub-NDARNF766VW2.
Moving sub-NDARNF954MK3 from yahya/cmi_bids_R1/sub-NDARNF954MK3 to yahya/cmi_bids_NC/sub-NDARNF954MK3.
Moving sub-NDARNF994TPA from yahya/cmi_bids_R1/sub-NDARNF994TPA to yahya/cmi_bids_NC/sub-NDARNF994TPA.
Moving sub-NDARNG689AAP from yahya/cmi_bids_R1/sub-NDARNG689AAP to yahya/cmi_bids_NC/sub-NDARNG689AAP.
Moving sub-NDARNJ894VH2 from yahya/cmi_bids_R1/sub-NDARNJ894VH2 to yahya/cmi_bids_NC/sub-NDARNJ894VH2.
Moving sub-NDARNL599TMZ from yahya/cmi_bids_R1/sub-NDARNL599TMZ to yahya/cmi_bids_NC/sub-NDARNL599TMZ.
Moving sub-NDARNM624PDC from yahya/cmi_bids_R1/sub-NDARNM624PDC to yahya/cmi_bids_NC/sub-NDARNM624PDC.
Moving sub-NDARNM834MY9 from yahya/cmi_bids_R1/sub-NDARNM834MY9 to yahya/cmi_bids_NC/sub-NDARNM834MY9.
Moving sub-NDARNN218UGY from yahya/cmi_bids_R1/sub-NDARNN218UGY to yahya/cmi_bids_NC/sub-NDARNN218UGY.
Moving sub-NDARNP399JVF from yahya/cmi_bids_R1/sub-NDARNP399JVF to yahya/cmi_bids_NC/sub-NDARNP399JVF.
Moving sub-NDARNP939DDQ from yahya/cmi_bids_R1/sub-NDARNP939DDQ to yahya/cmi_bids_NC/sub-NDARNP939DDQ.
Moving sub-NDARNT042GRA from yahya/cmi_bids_R1/sub-NDARNT042GRA to yahya/cmi_bids_NC/sub-NDARNT042GRA.
Moving sub-NDARNT572CMD from yahya/cmi_bids_R1/sub-NDARNT572CMD to yahya/cmi_bids_NC/sub-NDARNT572CMD.
Moving sub-NDARNT939YMG from yahya/cmi_bids_R1/sub-NDARNT939YMG to yahya/cmi_bids_NC/sub-NDARNT939YMG.
Moving sub-NDARNU249EDF from yahya/cmi_bids_R1/sub-NDARNU249EDF to yahya/cmi_bids_NC/sub-NDARNU249EDF.
Moving sub-NDARNU282ZYZ from yahya/cmi_bids_R1/sub-NDARNU282ZYZ to yahya/cmi_bids_NC/sub-NDARNU282ZYZ.
Moving sub-NDARNW182PJC from yahya/cmi_bids_R1/sub-NDARNW182PJC to yahya/cmi_bids_NC/sub-NDARNW182PJC.
Moving sub-NDARNW218ZBU from yahya/cmi_bids_R1/sub-NDARNW218ZBU to yahya/cmi_bids_NC/sub-NDARNW218ZBU.
Moving sub-NDARNW797PD6 from yahya/cmi_bids_R1/sub-NDARNW797PD6 to yahya/cmi_bids_NC/sub-NDARNW797PD6.
Moving sub-NDARNX795LFK from yahya/cmi_bids_R1/sub-NDARNX795LFK to yahya/cmi_bids_NC/sub-NDARNX795LFK.
Moving sub-NDARNY964EA0 from yahya/cmi_bids_R1/sub-NDARNY964EA0 to yahya/cmi_bids_NC/sub-NDARNY964EA0.
Moving sub-NDARPD977VX2 from yahya/cmi_bids_R1/sub-NDARPD977VX2 to yahya/cmi_bids_NC/sub-NDARPD977VX2.
Moving sub-NDARPE596LZL from yahya/cmi_bids_R1/sub-NDARPE596LZL to yahya/cmi_bids_NC/sub-NDARPE596LZL.
Moving sub-NDARPF179GNV from yahya/cmi_bids_R1/sub-NDARPF179GNV to yahya/cmi_bids_NC/sub-NDARPF179GNV.
Moving sub-NDARPK339NA6 from yahya/cmi_bids_R1/sub-NDARPK339NA6 to yahya/cmi_bids_NC/sub-NDARPK339NA6.
Moving sub-NDARPL721WTD from yahya/cmi_bids_R1/sub-NDARPL721WTD to yahya/cmi_bids_NC/sub-NDARPL721WTD.
Moving sub-NDARPM105MKA from yahya/cmi_bids_R1/sub-NDARPM105MKA to yahya/cmi_bids_NC/sub-NDARPM105MKA.
Moving sub-NDARPP703NX4 from yahya/cmi_bids_R1/sub-NDARPP703NX4 to yahya/cmi_bids_NC/sub-NDARPP703NX4.
Moving sub-NDARPV249ZRF from yahya/cmi_bids_R1/sub-NDARPV249ZRF to yahya/cmi_bids_NC/sub-NDARPV249ZRF.
Moving sub-NDARPW482TVE from yahya/cmi_bids_R1/sub-NDARPW482TVE to yahya/cmi_bids_NC/sub-NDARPW482TVE.
Moving sub-NDARPX155RF3 from yahya/cmi_bids_R1/sub-NDARPX155RF3 to yahya/cmi_bids_NC/sub-NDARPX155RF3.
Moving sub-NDARPX244EHJ from yahya/cmi_bids_R1/sub-NDARPX244EHJ to yahya/cmi_bids_NC/sub-NDARPX244EHJ.
Moving sub-NDARPZ621ZLE from yahya/cmi_bids_R1/sub-NDARPZ621ZLE to yahya/cmi_bids_NC/sub-NDARPZ621ZLE.
Moving sub-NDARRA314KW4 from yahya/cmi_bids_R1/sub-NDARRA314KW4 to yahya/cmi_bids_NC/sub-NDARRA314KW4.
Moving sub-NDARRA733VWX from yahya/cmi_bids_R1/sub-NDARRA733VWX to yahya/cmi_bids_NC/sub-NDARRA733VWX.
Moving sub-NDARRC819NLC from yahya/cmi_bids_R1/sub-NDARRC819NLC to yahya/cmi_bids_NC/sub-NDARRC819NLC.
Moving sub-NDARRD720XZK from yahya/cmi_bids_R1/sub-NDARRD720XZK to yahya/cmi_bids_NC/sub-NDARRD720XZK.
Moving sub-NDARRE333EKT from yahya/cmi_bids_R1/sub-NDARRE333EKT to yahya/cmi_bids_NC/sub-NDARRE333EKT.
Moving sub-NDARRG199RU4 from yahya/cmi_bids_R1/sub-NDARRG199RU4 to yahya/cmi_bids_NC/sub-NDARRG199RU4.
Moving sub-NDARRG415BJM from yahya/cmi_bids_R1/sub-NDARRG415BJM to yahya/cmi_bids_NC/sub-NDARRG415BJM.
Moving sub-NDARRG735TU5 from yahya/cmi_bids_R1/sub-NDARRG735TU5 to yahya/cmi_bids_NC/sub-NDARRG735TU5.
Moving sub-NDARRH725XYA from yahya/cmi_bids_R1/sub-NDARRH725XYA to yahya/cmi_bids_NC/sub-NDARRH725XYA.
Moving sub-NDARRJ728NMD from yahya/cmi_bids_R1/sub-NDARRJ728NMD to yahya/cmi_bids_NC/sub-NDARRJ728NMD.
Moving sub-NDARRK457MBX from yahya/cmi_bids_R1/sub-NDARRK457MBX to yahya/cmi_bids_NC/sub-NDARRK457MBX.
Moving sub-NDARRN619WHY from yahya/cmi_bids_R1/sub-NDARRN619WHY to yahya/cmi_bids_NC/sub-NDARRN619WHY.
Moving sub-NDARRP592GHK from yahya/cmi_bids_R1/sub-NDARRP592GHK to yahya/cmi_bids_NC/sub-NDARRP592GHK.
Moving sub-NDARRU501YED from yahya/cmi_bids_R1/sub-NDARRU501YED to yahya/cmi_bids_NC/sub-NDARRU501YED.
Moving sub-NDARRV638MJV from yahya/cmi_bids_R1/sub-NDARRV638MJV to yahya/cmi_bids_NC/sub-NDARRV638MJV.
Moving sub-NDARRW100AU0 from yahya/cmi_bids_R1/sub-NDARRW100AU0 to yahya/cmi_bids_NC/sub-NDARRW100AU0.
Moving sub-NDARRY112RAK from yahya/cmi_bids_R1/sub-NDARRY112RAK to yahya/cmi_bids_NC/sub-NDARRY112RAK.
Moving sub-NDARRZ199KNG from yahya/cmi_bids_R1/sub-NDARRZ199KNG to yahya/cmi_bids_NC/sub-NDARRZ199KNG.
Moving sub-NDARRZ979FZ4 from yahya/cmi_bids_R1/sub-NDARRZ979FZ4 to yahya/cmi_bids_NC/sub-NDARRZ979FZ4.
Moving sub-NDARTA808DEQ from yahya/cmi_bids_R1/sub-NDARTA808DEQ to yahya/cmi_bids_NC/sub-NDARTA808DEQ.
Moving sub-NDARTB552HP0 from yahya/cmi_bids_R1/sub-NDARTB552HP0 to yahya/cmi_bids_NC/sub-NDARTB552HP0.
Moving sub-NDARTD640PC5 from yahya/cmi_bids_R1/sub-NDARTD640PC5 to yahya/cmi_bids_NC/sub-NDARTD640PC5.
Moving sub-NDARTF833WXB from yahya/cmi_bids_R1/sub-NDARTF833WXB to yahya/cmi_bids_NC/sub-NDARTF833WXB.
Moving sub-NDARTG464MWG from yahya/cmi_bids_R1/sub-NDARTG464MWG to yahya/cmi_bids_NC/sub-NDARTG464MWG.
Moving sub-NDARTG810FRE from yahya/cmi_bids_R1/sub-NDARTG810FRE to yahya/cmi_bids_NC/sub-NDARTG810FRE.
Moving sub-NDARTH610GMK from yahya/cmi_bids_R1/sub-NDARTH610GMK to yahya/cmi_bids_NC/sub-NDARTH610GMK.
Moving sub-NDARTJ418GP0 from yahya/cmi_bids_R1/sub-NDARTJ418GP0 to yahya/cmi_bids_NC/sub-NDARTJ418GP0.
Moving sub-NDARTK185PBH from yahya/cmi_bids_R1/sub-NDARTK185PBH to yahya/cmi_bids_NC/sub-NDARTK185PBH.
Moving sub-NDARTK657DV6 from yahya/cmi_bids_R1/sub-NDARTK657DV6 to yahya/cmi_bids_NC/sub-NDARTK657DV6.
Moving sub-NDARTL336THT from yahya/cmi_bids_R1/sub-NDARTL336THT to yahya/cmi_bids_NC/sub-NDARTL336THT.
Moving sub-NDARTP190KAN from yahya/cmi_bids_R1/sub-NDARTP190KAN to yahya/cmi_bids_NC/sub-NDARTP190KAN.
Moving sub-NDARTR365NCY from yahya/cmi_bids_R1/sub-NDARTR365NCY to yahya/cmi_bids_NC/sub-NDARTR365NCY.
Moving sub-NDARTR811WH9 from yahya/cmi_bids_R1/sub-NDARTR811WH9 to yahya/cmi_bids_NC/sub-NDARTR811WH9.
Moving sub-NDARTR840XP1 from yahya/cmi_bids_R1/sub-NDARTR840XP1 to yahya/cmi_bids_NC/sub-NDARTR840XP1.
Moving sub-NDARTT242GNN from yahya/cmi_bids_R1/sub-NDARTT242GNN to yahya/cmi_bids_NC/sub-NDARTT242GNN.
Moving sub-NDARTU768MY1 from yahya/cmi_bids_R1/sub-NDARTU768MY1 to yahya/cmi_bids_NC/sub-NDARTU768MY1.
Moving sub-NDARTW939GJF from yahya/cmi_bids_R1/sub-NDARTW939GJF to yahya/cmi_bids_NC/sub-NDARTW939GJF.
Moving sub-NDARTX012JHM from yahya/cmi_bids_R1/sub-NDARTX012JHM to yahya/cmi_bids_NC/sub-NDARTX012JHM.
Moving sub-NDARUA421HT8 from yahya/cmi_bids_R1/sub-NDARUA421HT8 to yahya/cmi_bids_NC/sub-NDARUA421HT8.
Moving sub-NDARUD764NFJ from yahya/cmi_bids_R1/sub-NDARUD764NFJ to yahya/cmi_bids_NC/sub-NDARUD764NFJ.
Moving sub-NDARUE533XNH from yahya/cmi_bids_R1/sub-NDARUE533XNH to yahya/cmi_bids_NC/sub-NDARUE533XNH.
Moving sub-NDARUF069EHR from yahya/cmi_bids_R1/sub-NDARUF069EHR to yahya/cmi_bids_NC/sub-NDARUF069EHR.
Moving sub-NDARUF389TXE from yahya/cmi_bids_R1/sub-NDARUF389TXE to yahya/cmi_bids_NC/sub-NDARUF389TXE.
Moving sub-NDARUF935UL3 from yahya/cmi_bids_R1/sub-NDARUF935UL3 to yahya/cmi_bids_NC/sub-NDARUF935UL3.
Moving sub-NDARUG507AZX from yahya/cmi_bids_R1/sub-NDARUG507AZX to yahya/cmi_bids_NC/sub-NDARUG507AZX.
Moving sub-NDARUJ646APQ from yahya/cmi_bids_R1/sub-NDARUJ646APQ to yahya/cmi_bids_NC/sub-NDARUJ646APQ.
Moving sub-NDARUJ962NZB from yahya/cmi_bids_R1/sub-NDARUJ962NZB to yahya/cmi_bids_NC/sub-NDARUJ962NZB.
Moving sub-NDARUL341DD2 from yahya/cmi_bids_R1/sub-NDARUL341DD2 to yahya/cmi_bids_NC/sub-NDARUL341DD2.
Moving sub-NDARUL881JR9 from yahya/cmi_bids_R1/sub-NDARUL881JR9 to yahya/cmi_bids_NC/sub-NDARUL881JR9.
Moving sub-NDARUM569EV1 from yahya/cmi_bids_R1/sub-NDARUM569EV1 to yahya/cmi_bids_NC/sub-NDARUM569EV1.
Moving sub-NDARUM991EE8 from yahya/cmi_bids_R1/sub-NDARUM991EE8 to yahya/cmi_bids_NC/sub-NDARUM991EE8.
Moving sub-NDARUP101NXA from yahya/cmi_bids_R1/sub-NDARUP101NXA to yahya/cmi_bids_NC/sub-NDARUP101NXA.
Moving sub-NDARUV263YB5 from yahya/cmi_bids_R1/sub-NDARUV263YB5 to yahya/cmi_bids_NC/sub-NDARUV263YB5.
Moving sub-NDARUV418FB8 from yahya/cmi_bids_R1/sub-NDARUV418FB8 to yahya/cmi_bids_NC/sub-NDARUV418FB8.
Moving sub-NDARUX114RGJ from yahya/cmi_bids_R1/sub-NDARUX114RGJ to yahya/cmi_bids_NC/sub-NDARUX114RGJ.
Moving sub-NDARUY876VL1 from yahya/cmi_bids_R1/sub-NDARUY876VL1 to yahya/cmi_bids_NC/sub-NDARUY876VL1.
Moving sub-NDARVB607WW4 from yahya/cmi_bids_R1/sub-NDARVB607WW4 to yahya/cmi_bids_NC/sub-NDARVB607WW4.
Moving sub-NDARVB811FVD from yahya/cmi_bids_R1/sub-NDARVB811FVD to yahya/cmi_bids_NC/sub-NDARVB811FVD.
Moving sub-NDARVC246ZY8 from yahya/cmi_bids_R1/sub-NDARVC246ZY8 to yahya/cmi_bids_NC/sub-NDARVC246ZY8.
Moving sub-NDARVD547NLC from yahya/cmi_bids_R1/sub-NDARVD547NLC to yahya/cmi_bids_NC/sub-NDARVD547NLC.
Moving sub-NDARVE724GEF from yahya/cmi_bids_R1/sub-NDARVE724GEF to yahya/cmi_bids_NC/sub-NDARVE724GEF.
Moving sub-NDARVG148WHV from yahya/cmi_bids_R1/sub-NDARVG148WHV to yahya/cmi_bids_NC/sub-NDARVG148WHV.
Moving sub-NDARVG436WGG from yahya/cmi_bids_R1/sub-NDARVG436WGG to yahya/cmi_bids_NC/sub-NDARVG436WGG.
Moving sub-NDARVG461LA2 from yahya/cmi_bids_R1/sub-NDARVG461LA2 to yahya/cmi_bids_NC/sub-NDARVG461LA2.
Moving sub-NDARVG618BM6 from yahya/cmi_bids_R1/sub-NDARVG618BM6 to yahya/cmi_bids_NC/sub-NDARVG618BM6.
Moving sub-NDARVG971CHH from yahya/cmi_bids_R1/sub-NDARVG971CHH to yahya/cmi_bids_NC/sub-NDARVG971CHH.
Moving sub-NDARVH070WH6 from yahya/cmi_bids_R1/sub-NDARVH070WH6 to yahya/cmi_bids_NC/sub-NDARVH070WH6.
Moving sub-NDARVJ504DAA from yahya/cmi_bids_R1/sub-NDARVJ504DAA to yahya/cmi_bids_NC/sub-NDARVJ504DAA.
Moving sub-NDARVM685MER from yahya/cmi_bids_R1/sub-NDARVM685MER to yahya/cmi_bids_NC/sub-NDARVM685MER.
Moving sub-NDARVN415VF6 from yahya/cmi_bids_R1/sub-NDARVN415VF6 to yahya/cmi_bids_NC/sub-NDARVN415VF6.
Moving sub-NDARVN469KP6 from yahya/cmi_bids_R1/sub-NDARVN469KP6 to yahya/cmi_bids_NC/sub-NDARVN469KP6.
Moving sub-NDARVN646NZP from yahya/cmi_bids_R1/sub-NDARVN646NZP to yahya/cmi_bids_NC/sub-NDARVN646NZP.
Moving sub-NDARVN666JV7 from yahya/cmi_bids_R1/sub-NDARVN666JV7 to yahya/cmi_bids_NC/sub-NDARVN666JV7.
Moving sub-NDARVP281CJ4 from yahya/cmi_bids_R1/sub-NDARVP281CJ4 to yahya/cmi_bids_NC/sub-NDARVP281CJ4.
Moving sub-NDARVV248VW0 from yahya/cmi_bids_R1/sub-NDARVV248VW0 to yahya/cmi_bids_NC/sub-NDARVV248VW0.
Moving sub-NDARVX162AZU from yahya/cmi_bids_R1/sub-NDARVX162AZU to yahya/cmi_bids_NC/sub-NDARVX162AZU.
Moving sub-NDARVX292KKC from yahya/cmi_bids_R1/sub-NDARVX292KKC to yahya/cmi_bids_NC/sub-NDARVX292KKC.
Moving sub-NDARWB124EMA from yahya/cmi_bids_R1/sub-NDARWB124EMA to yahya/cmi_bids_NC/sub-NDARWB124EMA.
Moving sub-NDARWB685NUG from yahya/cmi_bids_R1/sub-NDARWB685NUG to yahya/cmi_bids_NC/sub-NDARWB685NUG.
Moving sub-NDARWC737UJ0 from yahya/cmi_bids_R1/sub-NDARWC737UJ0 to yahya/cmi_bids_NC/sub-NDARWC737UJ0.
Moving sub-NDARWC925WDX from yahya/cmi_bids_R1/sub-NDARWC925WDX to yahya/cmi_bids_NC/sub-NDARWC925WDX.
Moving sub-NDARWF122UUJ from yahya/cmi_bids_R1/sub-NDARWF122UUJ to yahya/cmi_bids_NC/sub-NDARWF122UUJ.
Moving sub-NDARWG831JJ8 from yahya/cmi_bids_R1/sub-NDARWG831JJ8 to yahya/cmi_bids_NC/sub-NDARWG831JJ8.
Moving sub-NDARWJ019VGU from yahya/cmi_bids_R1/sub-NDARWJ019VGU to yahya/cmi_bids_NC/sub-NDARWJ019VGU.
Moving sub-NDARWJ087HKJ from yahya/cmi_bids_R1/sub-NDARWJ087HKJ to yahya/cmi_bids_NC/sub-NDARWJ087HKJ.
Moving sub-NDARWK065NJ9 from yahya/cmi_bids_R1/sub-NDARWK065NJ9 to yahya/cmi_bids_NC/sub-NDARWK065NJ9.
Moving sub-NDARWM319UU2 from yahya/cmi_bids_R1/sub-NDARWM319UU2 to yahya/cmi_bids_NC/sub-NDARWM319UU2.
Moving sub-NDARWM654UTC from yahya/cmi_bids_R1/sub-NDARWM654UTC to yahya/cmi_bids_NC/sub-NDARWM654UTC.
Moving sub-NDARWR881WMX from yahya/cmi_bids_R1/sub-NDARWR881WMX to yahya/cmi_bids_NC/sub-NDARWR881WMX.
Moving sub-NDARWV155PRG from yahya/cmi_bids_R1/sub-NDARWV155PRG to yahya/cmi_bids_NC/sub-NDARWV155PRG.
Moving sub-NDARWV677EFC from yahya/cmi_bids_R1/sub-NDARWV677EFC to yahya/cmi_bids_NC/sub-NDARWV677EFC.
Moving sub-NDARWW901MTC from yahya/cmi_bids_R1/sub-NDARWW901MTC to yahya/cmi_bids_NC/sub-NDARWW901MTC.
Moving sub-NDARWX033HYK from yahya/cmi_bids_R1/sub-NDARWX033HYK to yahya/cmi_bids_NC/sub-NDARWX033HYK.
Moving sub-NDARWX380JJK from yahya/cmi_bids_R1/sub-NDARWX380JJK to yahya/cmi_bids_NC/sub-NDARWX380JJK.
Moving sub-NDARWY198BVY from yahya/cmi_bids_R1/sub-NDARWY198BVY to yahya/cmi_bids_NC/sub-NDARWY198BVY.
Moving sub-NDARWZ283CWB from yahya/cmi_bids_R1/sub-NDARWZ283CWB to yahya/cmi_bids_NC/sub-NDARWZ283CWB.
Moving sub-NDARWZ709DLY from yahya/cmi_bids_R1/sub-NDARWZ709DLY to yahya/cmi_bids_NC/sub-NDARWZ709DLY.
Moving sub-NDARXB704HFD from yahya/cmi_bids_R1/sub-NDARXB704HFD to yahya/cmi_bids_NC/sub-NDARXB704HFD.
Moving sub-NDARXC418YG7 from yahya/cmi_bids_R1/sub-NDARXC418YG7 to yahya/cmi_bids_NC/sub-NDARXC418YG7.
Moving sub-NDARXC534KT4 from yahya/cmi_bids_R1/sub-NDARXC534KT4 to yahya/cmi_bids_NC/sub-NDARXC534KT4.
Moving sub-NDARXC826NW7 from yahya/cmi_bids_R1/sub-NDARXC826NW7 to yahya/cmi_bids_NC/sub-NDARXC826NW7.
Moving sub-NDARXC878WB2 from yahya/cmi_bids_R1/sub-NDARXC878WB2 to yahya/cmi_bids_NC/sub-NDARXC878WB2.
Moving sub-NDARXD325BGG from yahya/cmi_bids_R1/sub-NDARXD325BGG to yahya/cmi_bids_NC/sub-NDARXD325BGG.
Moving sub-NDARXE684LUY from yahya/cmi_bids_R1/sub-NDARXE684LUY to yahya/cmi_bids_NC/sub-NDARXE684LUY.
Moving sub-NDARXF441RHQ from yahya/cmi_bids_R1/sub-NDARXF441RHQ to yahya/cmi_bids_NC/sub-NDARXF441RHQ.
Moving sub-NDARXF623GEL from yahya/cmi_bids_R1/sub-NDARXF623GEL to yahya/cmi_bids_NC/sub-NDARXF623GEL.
Moving sub-NDARXF956ZU6 from yahya/cmi_bids_R1/sub-NDARXF956ZU6 to yahya/cmi_bids_NC/sub-NDARXF956ZU6.
Moving sub-NDARXH017ZLE from yahya/cmi_bids_R1/sub-NDARXH017ZLE to yahya/cmi_bids_NC/sub-NDARXH017ZLE.
Moving sub-NDARXJ468UGL from yahya/cmi_bids_R1/sub-NDARXJ468UGL to yahya/cmi_bids_NC/sub-NDARXJ468UGL.
Moving sub-NDARXJ696AMX from yahya/cmi_bids_R1/sub-NDARXJ696AMX to yahya/cmi_bids_NC/sub-NDARXJ696AMX.
Moving sub-NDARXK164TNN from yahya/cmi_bids_R1/sub-NDARXK164TNN to yahya/cmi_bids_NC/sub-NDARXK164TNN.
Moving sub-NDARXK462WRZ from yahya/cmi_bids_R1/sub-NDARXK462WRZ to yahya/cmi_bids_NC/sub-NDARXK462WRZ.
Moving sub-NDARXL523GHX from yahya/cmi_bids_R1/sub-NDARXL523GHX to yahya/cmi_bids_NC/sub-NDARXL523GHX.
Moving sub-NDARXM398VU8 from yahya/cmi_bids_R1/sub-NDARXM398VU8 to yahya/cmi_bids_NC/sub-NDARXM398VU8.
Moving sub-NDARXN047RUT from yahya/cmi_bids_R1/sub-NDARXN047RUT to yahya/cmi_bids_NC/sub-NDARXN047RUT.
Moving sub-NDARXN719LXU from yahya/cmi_bids_R1/sub-NDARXN719LXU to yahya/cmi_bids_NC/sub-NDARXN719LXU.
Moving sub-NDARXU679ZE8 from yahya/cmi_bids_R1/sub-NDARXU679ZE8 to yahya/cmi_bids_NC/sub-NDARXU679ZE8.
Moving sub-NDARXU715EGL from yahya/cmi_bids_R1/sub-NDARXU715EGL to yahya/cmi_bids_NC/sub-NDARXU715EGL.
Moving sub-NDARXW933TUJ from yahya/cmi_bids_R1/sub-NDARXW933TUJ to yahya/cmi_bids_NC/sub-NDARXW933TUJ.
Moving sub-NDARXX895FNJ from yahya/cmi_bids_R1/sub-NDARXX895FNJ to yahya/cmi_bids_NC/sub-NDARXX895FNJ.
Moving sub-NDARXY337ZH9 from yahya/cmi_bids_R1/sub-NDARXY337ZH9 to yahya/cmi_bids_NC/sub-NDARXY337ZH9.
Moving sub-NDARYA496WZD from yahya/cmi_bids_R1/sub-NDARYA496WZD to yahya/cmi_bids_NC/sub-NDARYA496WZD.
Moving sub-NDARYB204HKD from yahya/cmi_bids_R1/sub-NDARYB204HKD to yahya/cmi_bids_NC/sub-NDARYB204HKD.
Moving sub-NDARYE814TBX from yahya/cmi_bids_R1/sub-NDARYE814TBX to yahya/cmi_bids_NC/sub-NDARYE814TBX.
Moving sub-NDARYH110YV9 from yahya/cmi_bids_R1/sub-NDARYH110YV9 to yahya/cmi_bids_NC/sub-NDARYH110YV9.
Moving sub-NDARYH480GTD from yahya/cmi_bids_R1/sub-NDARYH480GTD to yahya/cmi_bids_NC/sub-NDARYH480GTD.
Moving sub-NDARYH996DA9 from yahya/cmi_bids_R1/sub-NDARYH996DA9 to yahya/cmi_bids_NC/sub-NDARYH996DA9.
Moving sub-NDARYJ389DWX from yahya/cmi_bids_R1/sub-NDARYJ389DWX to yahya/cmi_bids_NC/sub-NDARYJ389DWX.
Moving sub-NDARYJ536MCR from yahya/cmi_bids_R1/sub-NDARYJ536MCR to yahya/cmi_bids_NC/sub-NDARYJ536MCR.
Moving sub-NDARYK942YHY from yahya/cmi_bids_R1/sub-NDARYK942YHY to yahya/cmi_bids_NC/sub-NDARYK942YHY.
Moving sub-NDARYL272HDW from yahya/cmi_bids_R1/sub-NDARYL272HDW to yahya/cmi_bids_NC/sub-NDARYL272HDW.
Moving sub-NDARYL438DCK from yahya/cmi_bids_R1/sub-NDARYL438DCK to yahya/cmi_bids_NC/sub-NDARYL438DCK.
Moving sub-NDARYM257RR6 from yahya/cmi_bids_R1/sub-NDARYM257RR6 to yahya/cmi_bids_NC/sub-NDARYM257RR6.
Moving sub-NDARYM832PX3 from yahya/cmi_bids_R1/sub-NDARYM832PX3 to yahya/cmi_bids_NC/sub-NDARYM832PX3.
Moving sub-NDARYN484LLR from yahya/cmi_bids_R1/sub-NDARYN484LLR to yahya/cmi_bids_NC/sub-NDARYN484LLR.
Moving sub-NDARYP516VUU from yahya/cmi_bids_R1/sub-NDARYP516VUU to yahya/cmi_bids_NC/sub-NDARYP516VUU.
Moving sub-NDARYR538EP0 from yahya/cmi_bids_R1/sub-NDARYR538EP0 to yahya/cmi_bids_NC/sub-NDARYR538EP0.
Moving sub-NDARYR771VED from yahya/cmi_bids_R1/sub-NDARYR771VED to yahya/cmi_bids_NC/sub-NDARYR771VED.
Moving sub-NDARYT389KC1 from yahya/cmi_bids_R1/sub-NDARYT389KC1 to yahya/cmi_bids_NC/sub-NDARYT389KC1.
Moving sub-NDARYU323ZDJ from yahya/cmi_bids_R1/sub-NDARYU323ZDJ to yahya/cmi_bids_NC/sub-NDARYU323ZDJ.
Moving sub-NDARYU620RH9 from yahya/cmi_bids_R1/sub-NDARYU620RH9 to yahya/cmi_bids_NC/sub-NDARYU620RH9.
Moving sub-NDARYW903VN8 from yahya/cmi_bids_R1/sub-NDARYW903VN8 to yahya/cmi_bids_NC/sub-NDARYW903VN8.
Moving sub-NDARYX551LBY from yahya/cmi_bids_R1/sub-NDARYX551LBY to yahya/cmi_bids_NC/sub-NDARYX551LBY.
Moving sub-NDARYY218AGA from yahya/cmi_bids_R1/sub-NDARYY218AGA to yahya/cmi_bids_NC/sub-NDARYY218AGA.
Moving sub-NDARYZ143NTF from yahya/cmi_bids_R1/sub-NDARYZ143NTF to yahya/cmi_bids_NC/sub-NDARYZ143NTF.
Moving sub-NDARYZ408VWW from yahya/cmi_bids_R1/sub-NDARYZ408VWW to yahya/cmi_bids_NC/sub-NDARYZ408VWW.
Moving sub-NDARZA694WHF from yahya/cmi_bids_R1/sub-NDARZA694WHF to yahya/cmi_bids_NC/sub-NDARZA694WHF.
Moving sub-NDARZB377WZJ from yahya/cmi_bids_R1/sub-NDARZB377WZJ to yahya/cmi_bids_NC/sub-NDARZB377WZJ.
Moving sub-NDARZD991YLG from yahya/cmi_bids_R1/sub-NDARZD991YLG to yahya/cmi_bids_NC/sub-NDARZD991YLG.
Moving sub-NDARZE542ZVH from yahya/cmi_bids_R1/sub-NDARZE542ZVH to yahya/cmi_bids_NC/sub-NDARZE542ZVH.
Moving sub-NDARZF949WTW from yahya/cmi_bids_R1/sub-NDARZF949WTW to yahya/cmi_bids_NC/sub-NDARZF949WTW.
Moving sub-NDARZG263HRK from yahya/cmi_bids_R1/sub-NDARZG263HRK to yahya/cmi_bids_NC/sub-NDARZG263HRK.
Moving sub-NDARZH451LRZ from yahya/cmi_bids_R1/sub-NDARZH451LRZ to yahya/cmi_bids_NC/sub-NDARZH451LRZ.
Moving sub-NDARZH517ZVK from yahya/cmi_bids_R1/sub-NDARZH517ZVK to yahya/cmi_bids_NC/sub-NDARZH517ZVK.
Moving sub-NDARZH629NVF from yahya/cmi_bids_R1/sub-NDARZH629NVF to yahya/cmi_bids_NC/sub-NDARZH629NVF.
Moving sub-NDARZJ460RWZ from yahya/cmi_bids_R1/sub-NDARZJ460RWZ to yahya/cmi_bids_NC/sub-NDARZJ460RWZ.
Moving sub-NDARZJ607YLU from yahya/cmi_bids_R1/sub-NDARZJ607YLU to yahya/cmi_bids_NC/sub-NDARZJ607YLU.
Moving sub-NDARZL724HAX from yahya/cmi_bids_R1/sub-NDARZL724HAX to yahya/cmi_bids_NC/sub-NDARZL724HAX.
Moving sub-NDARZN899JCM from yahya/cmi_bids_R1/sub-NDARZN899JCM to yahya/cmi_bids_NC/sub-NDARZN899JCM.
Moving sub-NDARZP564MHU from yahya/cmi_bids_R1/sub-NDARZP564MHU to yahya/cmi_bids_NC/sub-NDARZP564MHU.
Moving sub-NDARZR567HWG from yahya/cmi_bids_R1/sub-NDARZR567HWG to yahya/cmi_bids_NC/sub-NDARZR567HWG.
Moving sub-NDARZT772PU4 from yahya/cmi_bids_R1/sub-NDARZT772PU4 to yahya/cmi_bids_NC/sub-NDARZT772PU4.
Moving sub-NDARZV766YXP from yahya/cmi_bids_R1/sub-NDARZV766YXP to yahya/cmi_bids_NC/sub-NDARZV766YXP.
Moving sub-NDARZW013RUH from yahya/cmi_bids_R1/sub-NDARZW013RUH to yahya/cmi_bids_NC/sub-NDARZW013RUH.
Moving sub-NDARZY019GNZ from yahya/cmi_bids_R1/sub-NDARZY019GNZ to yahya/cmi_bids_NC/sub-NDARZY019GNZ.
Processing participants.tsv in yahya/cmi_bids_R2...
Found non-commercial subjects in yahya/cmi_bids_R2.
Moving sub-NDARAN814UPR from yahya/cmi_bids_R2/sub-NDARAN814UPR to yahya/cmi_bids_NC/sub-NDARAN814UPR.
Moving sub-NDARFK477WX9 from yahya/cmi_bids_R2/sub-NDARFK477WX9 to yahya/cmi_bids_NC/sub-NDARFK477WX9.
Moving sub-NDARHJ945PV0 from yahya/cmi_bids_R2/sub-NDARHJ945PV0 to yahya/cmi_bids_NC/sub-NDARHJ945PV0.
Moving sub-NDARRZ653HKY from yahya/cmi_bids_R2/sub-NDARRZ653HKY to yahya/cmi_bids_NC/sub-NDARRZ653HKY.
Processing participants.tsv in yahya/cmi_bids_R3...
Found non-commercial subjects in yahya/cmi_bids_R3.
Moving sub-NDARRC190NKB from yahya/cmi_bids_R3/sub-NDARRC190NKB to yahya/cmi_bids_NC/sub-NDARRC190NKB.
Processing participants.tsv in yahya/cmi_bids_R4...
No non-commercial subjects found in yahya/cmi_bids_R4.
Processing participants.tsv in yahya/cmi_bids_R5...
No non-commercial subjects found in yahya/cmi_bids_R5.
Processing participants.tsv in yahya/cmi_bids_R6...
No non-commercial subjects found in yahya/cmi_bids_R6.
Processing participants.tsv in yahya/cmi_bids_R7...
No non-commercial subjects found in yahya/cmi_bids_R7.
Processing participants.tsv in yahya/cmi_bids_R8...
No non-commercial subjects found in yahya/cmi_bids_R8.
Processing participants.tsv in yahya/cmi_bids_R9...
No non-commercial subjects found in yahya/cmi_bids_R9.
Processing participants.tsv in yahya/cmi_bids_R10...
No non-commercial subjects found in yahya/cmi_bids_R10.
Processing participants.tsv in yahya/cmi_bids_R11...
No non-commercial subjects found in yahya/cmi_bids_R11.
Writing updated participants.tsv for yahya/cmi_bids_NC dataset.
Copying root files from yahya/cmi_bids_R12 to yahya/cmi_bids_NC (excluding participants.tsv)...
Copied task-symbolSearch_eeg.json to yahya/cmi_bids_NC.
Copied task-seqLearning8target_events.json to yahya/cmi_bids_NC.
Copied task-surroundSupp_eeg.json to yahya/cmi_bids_NC.
Copied task-contrastChangeDetection_eeg.json to yahya/cmi_bids_NC.
Copied task-seqLearning8target_eeg.json to yahya/cmi_bids_NC.
Copied task-DespicableMe_eeg.json to yahya/cmi_bids_NC.
Copied task-RestingState_events.json to yahya/cmi_bids_NC.
Copied participants.json to yahya/cmi_bids_NC.
Copied task-surroundSupp_events.json to yahya/cmi_bids_NC.
Copied dataset_description.json to yahya/cmi_bids_NC.
Copied README to yahya/cmi_bids_NC.
Copied task-FunwithFractals_events.json to yahya/cmi_bids_NC.
Copied task-ThePresent_eeg.json to yahya/cmi_bids_NC.
Copied task-symbolSearch_events.json to yahya/cmi_bids_NC.
Copied task-ThePresent_events.json to yahya/cmi_bids_NC.
Copied task-seqLearning6target_events.json to yahya/cmi_bids_NC.
Copied task-contrastChangeDetection_events.json to yahya/cmi_bids_NC.
Copied task-FunwithFractals_eeg.json to yahya/cmi_bids_NC.
Copied task-RestingState_eeg.json to yahya/cmi_bids_NC.
Copied task-DespicableMe_events.json to yahya/cmi_bids_NC.
Copied task-seqLearning6target_eeg.json to yahya/cmi_bids_NC.
Copied task-DiaryOfAWimpyKid_events.json to yahya/cmi_bids_NC.
Copied task-DiaryOfAWimpyKid_eeg.json to yahya/cmi_bids_NC.
Process completed.
"""

def extract_subjects_and_releases(log):
    # Regular expression to match lines indicating subjects being moved along with their release number
    pattern = r"Moving (sub-[^\s]+) from yahya/cmi_bids_(R\d+)/sub-[^\s]+ to"
    
    # Dictionary to hold subjects and their respective release numbers
    subjects_releases = []

    # Find all matches in the log data
    matches = re.findall(pattern, log)
    for subject, release in matches:
        subjects_releases.append((subject, release))
    
    return subjects_releases

# Extract subjects and their corresponding releases from the log data
subjects_releases_moved = extract_subjects_and_releases(log_data)

# Write the subject-release pairs to a CSV file
with open('subjects_moved.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Subject ID', 'Release'])  # Writing header
    writer.writerows(subjects_releases_moved)

print("CSV file 'subjects_moved.csv' has been created with the extracted data.")
# Out:
# CSV file 'subjects_moved.csv' has been created with the extracted data.
